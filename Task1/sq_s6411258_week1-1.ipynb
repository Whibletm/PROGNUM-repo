# %% [markdown]
# * Name: Joe Whibley
# * Username: jcbwhibley
# * Student s-number: s6411258
# * Group (AS1, etc.): AS6

# %% [markdown]
# x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![Monkey-Selfie.png](attachment:c9f94f55-1f23-4d6f-88aa-c36961531253.png)

# %%
x=6
x*=5
x*=4
x*=3
x*=2


print(x)
# Out:
# 720

# %%
import scipy.constants as sc
h = sc.h
c = sc.c
frequency = (2.42*10**28)
wavelength = sc.c/frequency

Energy = h*c/wavelength
print("The Energy is:", Energy)
# Out:
# The Energy is: 1.6035089762999996e-05

# %%
import scipy.constants as sc
c = sc.c
G = sc.G
mass_moon = (7.342*10**22)
mass_earth = (5.9722*10**24)
radius = 385000.6*10**3
force = (G*mass_moon*mass_earth)/(radius**2)

print("The Force is", force)
# Out:
# The Force is 1.974384051807571e+20

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
#end usually allows you to shoose what appears at the end of the print, if you put " " it just skips to the next line
# Out:
# 103.142857142857143

# %% [markdown]
# 1.15
# pwd /Users/users/jcbwhibley/downloads
# . is downloads, .. is home
#
# 1.17 - symbolic link ls
#
# 1.21 - setting up dolphin + screen shot FINISH
#
# 1.19 - lists anything with (anything)-a digit-a dot-either c or o. [the brackets represent a range], ls *[0-9]*.co means the same but only ending in co
